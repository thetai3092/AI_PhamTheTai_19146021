# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
kt_hinh=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=kt_hinh.flow_from_directory('/content/drive/MyDrive/BTVNpic/hinh3nguoi/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 115 images belonging to 3 classes.

# %%
validation_data=kt_hinh.flow_from_directory('/content/drive/MyDrive/BTVNpic/hinh3nguoi/Validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 18 images belonging to 3 classes.

# %%
training_data.class_indices
# Out:
# {'train_nguyen': 0, 'train_tai': 1, 'train_toan': 2}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.3))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(training_data,epochs=100,batch_size=64,verbose=1, validation_data=validation_data, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 43s 7s/step - loss: 17.3494 - accuracy: 0.2957 - val_loss: 1.3787 - val_accuracy: 0.3889
# Epoch 2/100
# 4/4 [==============================] - 1s 398ms/step - loss: 1.1831 - accuracy: 0.4087 - val_loss: 0.9776 - val_accuracy: 0.5556
# Epoch 3/100
# 4/4 [==============================] - 1s 341ms/step - loss: 1.1379 - accuracy: 0.5478 - val_loss: 1.1294 - val_accuracy: 0.3333
# Epoch 4/100
# 4/4 [==============================] - 1s 331ms/step - loss: 0.9695 - accuracy: 0.5652 - val_loss: 0.7744 - val_accuracy: 0.7778
# Epoch 5/100
# 4/4 [==============================] - 1s 399ms/step - loss: 0.7813 - accuracy: 0.6870 - val_loss: 0.8237 - val_accuracy: 0.5556
# Epoch 6/100
# 4/4 [==============================] - 1s 392ms/step - loss: 0.6836 - accuracy: 0.7130 - val_loss: 0.4280 - val_accuracy: 0.9444
# Epoch 7/100
# 4/4 [==============================] - 1s 349ms/step - loss: 0.3397 - accuracy: 0.8957 - val_loss: 0.5299 - val_accuracy: 0.8889
# Epoch 8/100
# 4/4 [==============================] - 1s 399ms/step - loss: 0.2438 - accuracy: 0.9130 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 9/100
# 4/4 [==============================] - 1s 332ms/step - loss: 0.2339 - accuracy: 0.9391 - val_loss: 0.1687 - val_accuracy: 0.9444
# Epoch 10/100
# 4/4 [==============================] - 1s 348ms/step - loss: 0.1204 - accuracy: 0.9565 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 11/100
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0683 - accuracy: 0.9826 - val_loss: 0.0691 - val_accuracy: 1.0000
# Epoch 12/100
# 4/4 [==============================] - 1s 348ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 13/100
# 4/4 [==============================] - 1s 388ms/step - loss: 0.0362 - accuracy: 0.9913 - val_loss: 0.1755 - val_accuracy: 0.9444
# Epoch 14/100
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0322 - accuracy: 0.9913 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 15/100
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0422 - accuracy: 0.9826 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 16/100
# 4/4 [==============================] - 1s 337ms/step - loss: 0.0367 - accuracy: 0.9826 - val_loss: 0.4215 - val_accuracy: 0.8889
# Epoch 17/100
# 4/4 [==============================] - 1s 394ms/step - loss: 0.1136 - accuracy: 0.9565 - val_loss: 0.0669 - val_accuracy: 0.9444
# Epoch 18/100
# 4/4 [==============================] - 2s 457ms/step - loss: 0.1547 - accuracy: 0.9652 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 19/100
# 4/4 [==============================] - 1s 334ms/step - loss: 0.0370 - accuracy: 0.9913 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 20/100
# 4/4 [==============================] - 1s 333ms/step - loss: 0.0463 - accuracy: 0.9913 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 21/100
# 4/4 [==============================] - 1s 397ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.8333
# Epoch 22/100
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0320 - accuracy: 0.9913 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 23/100
# 4/4 [==============================] - 1s 336ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 24/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0104 - accuracy: 0.9913 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 25/100
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0140 - accuracy: 0.9913 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 26/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 9.6113e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 4/4 [==============================] - 1s 396ms/step - loss: 9.2336e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 1s 354ms/step - loss: 6.2854e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 1s 343ms/step - loss: 3.7607e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 1s 335ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 1s 341ms/step - loss: 5.2949e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 1s 396ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 6.9088e-04 - val_accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 1s 336ms/step - loss: 0.0534 - accuracy: 0.9913 - val_loss: 5.0728e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 1s 338ms/step - loss: 0.0576 - accuracy: 0.9652 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0823 - accuracy: 0.9913 - val_loss: 0.3048 - val_accuracy: 0.8889
# Epoch 36/100
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0393 - accuracy: 0.9913 - val_loss: 8.0100e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0564 - accuracy: 0.9913 - val_loss: 0.0433 - val_accuracy: 0.9444
# Epoch 38/100
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0299 - accuracy: 0.9826 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 1s 392ms/step - loss: 0.0288 - accuracy: 0.9826 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0281 - accuracy: 0.9826 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 1s 339ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 1s 339ms/step - loss: 0.0443 - accuracy: 0.9826 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 1s 401ms/step - loss: 0.0174 - accuracy: 0.9913 - val_loss: 0.1277 - val_accuracy: 0.9444
# Epoch 44/100
# 4/4 [==============================] - 1s 352ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9444
# Epoch 45/100
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 7.4919e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 1s 404ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3197e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 8.3086e-05 - val_accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 1s 398ms/step - loss: 3.6231e-04 - accuracy: 1.0000 - val_loss: 5.9995e-05 - val_accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 1s 346ms/step - loss: 3.2551e-05 - accuracy: 1.0000 - val_loss: 9.3105e-05 - val_accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 1s 399ms/step - loss: 2.0103e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.2243e-05 - val_accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.5178e-05 - val_accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 1s 354ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 1s 332ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 6.9751e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 1s 393ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.9452e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 1s 344ms/step - loss: 2.4547e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 1s 354ms/step - loss: 2.4206e-05 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 1s 347ms/step - loss: 7.2699e-05 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 1s 396ms/step - loss: 1.5543e-05 - accuracy: 1.0000 - val_loss: 6.9540e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 1s 355ms/step - loss: 3.4472e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9444
# Epoch 64/100
# 4/4 [==============================] - 2s 356ms/step - loss: 1.5068e-05 - accuracy: 1.0000 - val_loss: 2.7883e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 1s 354ms/step - loss: 2.6312e-05 - accuracy: 1.0000 - val_loss: 2.4030e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 1s 352ms/step - loss: 2.4424e-05 - accuracy: 1.0000 - val_loss: 6.3395e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 1s 336ms/step - loss: 2.4416e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 1s 347ms/step - loss: 1.7911e-05 - accuracy: 1.0000 - val_loss: 4.4739e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 1s 333ms/step - loss: 5.9031e-05 - accuracy: 1.0000 - val_loss: 1.7031e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 1s 405ms/step - loss: 1.7030e-05 - accuracy: 1.0000 - val_loss: 5.2313e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 1s 350ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9444
# Epoch 72/100
# 4/4 [==============================] - 1s 405ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9444
# Epoch 73/100
# 4/4 [==============================] - 2s 357ms/step - loss: 5.6547e-04 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9444

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("Nhandien3nguoi.h5")

# %%
model_nhandien=load_model('Nhandien3nguoi.h5')

# %%
img=load_img("/content/drive/MyDrive/BTVNpic/hinh3nguoi/nhandienmat/nguyen.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='Nguyen'
if round(result[0][1])==1:
  prediction='Tai'
if round(result[0][2])==1:
  prediction='Toan'
print(prediction)
# Out:
# Nguyen

# %%
img=load_img("/content/drive/MyDrive/BTVNpic/hinh3nguoi/nhandienmat/tai.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='Nguyen'
if round(result[0][1])==1:
  prediction='Tai'
if round(result[0][2])==1:
  prediction='Toan'
print(prediction)
# Out:
# Tai

# %%
img=load_img("/content/drive/MyDrive/BTVNpic/hinh3nguoi/nhandienmat/toan.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='Nguyen'
if round(result[0][1])==1:
  prediction='Tai'
if round(result[0][2])==1:
  prediction='Toan'
print(prediction)
# Out:
# Toan
